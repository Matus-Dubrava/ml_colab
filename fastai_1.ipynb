# %% [markdown]
# <a href="https://colab.research.google.com/github/Matus-Dubrava/ml_colab/blob/master/fastai_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %reload_ext autoreload
# %autoreload 2

# %%
from fastai import *
from fastai.vision import * 
import matplotlib.pyplot as plt
plt.style.use("seaborn")

# %%
path = untar_data(URLs.PETS); path
# Out:
# PosixPath('/root/.fastai/data/oxford-iiit-pet')

# %%
path.ls()
# Out:
# [PosixPath('/root/.fastai/data/oxford-iiit-pet/annotations'),
#  PosixPath('/root/.fastai/data/oxford-iiit-pet/images')]

# %%
path_anno = path/"annotations"
path_img = path/"images"

# %%
fnames = get_image_files(path_img)
fnames[:5]
# Out:
# [PosixPath('/root/.fastai/data/oxford-iiit-pet/images/chihuahua_66.jpg'),
#  PosixPath('/root/.fastai/data/oxford-iiit-pet/images/scottish_terrier_129.jpg'),
#  PosixPath('/root/.fastai/data/oxford-iiit-pet/images/British_Shorthair_59.jpg'),
#  PosixPath('/root/.fastai/data/oxford-iiit-pet/images/Russian_Blue_172.jpg'),
#  PosixPath('/root/.fastai/data/oxford-iiit-pet/images/pomeranian_1.jpg')]

# %%
np.random.seed(2)
pat = r"/([^/]+)_\d+.jpg$"

# %%
data = ImageDataBunch.from_name_re(path_img, fnames, pat, ds_tfms=get_transforms(), size=224)
data.normalize(imagenet_stats)
# Out:
# ImageDataBunch;
#
# Train: LabelList (5912 items)
# x: ImageList
# Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224)
# y: CategoryList
# chihuahua,scottish_terrier,British_Shorthair,scottish_terrier,yorkshire_terrier
# Path: /root/.fastai/data/oxford-iiit-pet/images;
#
# Valid: LabelList (1478 items)
# x: ImageList
# Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224)
# y: CategoryList
# Bengal,newfoundland,wheaten_terrier,samoyed,scottish_terrier
# Path: /root/.fastai/data/oxford-iiit-pet/images;
#
# Test: None

# %%
data.show_batch(rows=3, figsize=(7, 6))

# %%
print(data.classes)
len(data.classes), data.c
# Out:
# ['Abyssinian', 'Bengal', 'Birman', 'Bombay', 'British_Shorthair', 'Egyptian_Mau', 'Maine_Coon', 'Persian', 'Ragdoll', 'Russian_Blue', 'Siamese', 'Sphynx', 'american_bulldog', 'american_pit_bull_terrier', 'basset_hound', 'beagle', 'boxer', 'chihuahua', 'english_cocker_spaniel', 'english_setter', 'german_shorthaired', 'great_pyrenees', 'havanese', 'japanese_chin', 'keeshond', 'leonberger', 'miniature_pinscher', 'newfoundland', 'pomeranian', 'pug', 'saint_bernard', 'samoyed', 'scottish_terrier', 'shiba_inu', 'staffordshire_bull_terrier', 'wheaten_terrier', 'yorkshire_terrier']
# (37, 37)

# %%
learn = cnn_learner(data, models.resnet34, metrics=error_rate)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet34-333f7ec4.pth" to /root/.cache/torch/checkpoints/resnet34-333f7ec4.pth
# ...

# %%
learn.fit_one_cycle(4)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.386697</td>
#       <td>0.310334</td>
#       <td>0.103518</td>
#       <td>01:27</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.606278</td>
#       <td>0.272814</td>
#       <td>0.083221</td>
#       <td>01:25</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.388391</td>
#       <td>0.221942</td>
#       <td>0.070365</td>
#       <td>01:26</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.263383</td>
#       <td>0.206235</td>
#       <td>0.064276</td>
#       <td>01:26</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save("/home/stage-1")

# %%
interp = ClassificationInterpretation.from_learner(learn)

# %%
interp.plot_top_losses(9, figsize=(15, 11))

# %%
doc(interp.plot_top_losses)
# Out:
# <h4 id="_cl_int_plot_top_losses" class="doc_header"><code>_cl_int_plot_top_losses</code><a href="https://github.com/fastai/fastai/blob/master/fastai/vision/learner.py#L163" class="source_link" style="float:right">[source]</a><a class="source_link" data-toggle="collapse" data-target="#_cl_int_plot_top_losses-pytest" style="float:right; padding-right:10px">[test]</a></h4><blockquote><p><code>_cl_int_plot_top_losses</code>(<strong><code>k</code></strong>, <strong><code>largest</code></strong>=<strong><em><code>True</code></em></strong>, <strong><code>figsize</code></strong>=<strong><em><code>(12, 12)</code></em></strong>, <strong><code>heatmap</code></strong>:<code>bool</code>=<strong><em><code>False</code></em></strong>, <strong><code>heatmap_thresh</code></strong>:<code>int</code>=<strong><em><code>16</code></em></strong>, <strong><code>alpha</code></strong>:<code>float</code>=<strong><em><code>0.6</code></em></strong>, <strong><code>cmap</code></strong>:<code>str</code>=<strong><em><
# ...

# %%
interp.plot_confusion_matrix(figsize=(12, 12), dpi=60)

# %%
interp.most_confused(min_val=2)
# Out:
# [('Bengal', 'Egyptian_Mau', 5),
#  ('Egyptian_Mau', 'Bengal', 5),
#  ('Ragdoll', 'Birman', 5),
#  ('Maine_Coon', 'Ragdoll', 4),
#  ('american_pit_bull_terrier', 'american_bulldog', 4),
#  ('american_pit_bull_terrier', 'staffordshire_bull_terrier', 4),
#  ('staffordshire_bull_terrier', 'american_bulldog', 4),
#  ('Birman', 'Ragdoll', 3),
#  ('Russian_Blue', 'British_Shorthair', 3),
#  ('basset_hound', 'beagle', 3),
#  ('boxer', 'american_bulldog', 3),
#  ('chihuahua', 'miniature_pinscher', 3),
#  ('Abyssinian', 'Russian_Blue', 2),
#  ('Bengal', 'Abyssinian', 2),
#  ('Birman', 'Siamese', 2),
#  ('Persian', 'Maine_Coon', 2),
#  ('Siamese', 'Birman', 2),
#  ('basset_hound', 'american_pit_bull_terrier', 2),
#  ('chihuahua', 'american_pit_bull_terrier', 2),
#  ('english_cocker_spaniel', 'english_setter', 2),
#  ('miniature_pinscher', 'american_pit_bull_terrier', 2)]

# %%
learn.unfreeze()

# %%
learn.fit_one_cycle(1)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.741299</td>
#       <td>0.369487</td>
#       <td>0.110961</td>
#       <td>01:34</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.load("/home/stage-1")

# %%
learn.lr_find()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='2', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/2 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
# ...

# %%
learn.recorder.plot()

# %%
learn.unfreeze()
learn.fit_one_cycle(2, max_lr=slice(1e-6, 1e-4))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.239591</td>
#       <td>0.201700</td>
#       <td>0.061570</td>
#       <td>01:34</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.226534</td>
#       <td>0.191627</td>
#       <td>0.056834</td>
#       <td>01:34</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save("/home/stage-2")

# %%
data = ImageDataBunch.from_name_re(path_img, fnames, pat, ds_tfms=get_transforms(), size=299, bs=32)
data.normalize(imagenet_stats)
# Out:
# ImageDataBunch;
#
# Train: LabelList (5912 items)
# x: ImageList
# Image (3, 299, 299),Image (3, 299, 299),Image (3, 299, 299),Image (3, 299, 299),Image (3, 299, 299)
# y: CategoryList
# chihuahua,scottish_terrier,British_Shorthair,Russian_Blue,scottish_terrier
# Path: /root/.fastai/data/oxford-iiit-pet/images;
#
# Valid: LabelList (1478 items)
# x: ImageList
# Image (3, 299, 299),Image (3, 299, 299),Image (3, 299, 299),Image (3, 299, 299),Image (3, 299, 299)
# y: CategoryList
# Ragdoll,yorkshire_terrier,keeshond,Birman,wheaten_terrier
# Path: /root/.fastai/data/oxford-iiit-pet/images;
#
# Test: None

# %%
learn = cnn_learner(data, models.resnet50, metrics=error_rate)

# %%
learn.fit_one_cycle(5)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.728693</td>
#       <td>0.405994</td>
#       <td>0.116373</td>
#       <td>02:29</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.495774</td>
#       <td>0.265258</td>
#       <td>0.073748</td>
#       <td>02:22</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.358026</td>
#       <td>0.246310</td>
#       <td>0.074425</td>
#       <td>02:21</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.232980</td>
#       <td>0.183921</td>
#       <td>0.053451</td>
#       <td>02:19</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.163962</td>
#       <td>0.175462</td>
#       <td>0.050068</td>
#       <td>02:19</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.lr_find()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
# ...

# %%
learn.recorder.plot()
